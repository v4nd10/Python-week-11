# %% [markdown]
# <a href="https://colab.research.google.com/github/v4nd10/Python-week-11/blob/main/Pertemuan_11_images_classcification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
ls
# Out:
#  coast_cdmc866.jpg             tugaspy.ipynb          'Tugas Python minggu 11'/
#  IMG_20200815_201716_HDR.jpg  'Tugas Python'/
#  nnmodel_scene/                Tugas-Python-main.zip

# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.optimizers import Adam
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image
from imutils import paths
import numpy as np
import os

# %%
# grab all image paths in the input dataset directory, then initialize
# our list of images and corresponding class labels
print("[INFO] loading images...")
imagePaths = paths.list_images("Tugas Python minggu 11")
data = []
labels = []
# Out:
# [INFO] loading images...

# %%
for imagePath in imagePaths:
  # load the input image from disk, resize it to 64x64 pixels, scale
  # the pixel intensities to the range [0, 1], and then update our
  # image list
  image = Image.open(imagePath)
  # prepocessing
  image = np.array(image.resize((64, 64))) / 255.0
  data.append(image)
  # extract the class label from the file path and update the
  #label list
  label = imagePath.split(os.path.sep)[-2]
  labels.append(label)

# %%
print(labels)
# Out:
# ['GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_01', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_05', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_03', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', 'GMB_02', ...

# %%
# encode the labes, converting them from strings to integers
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
print(labels)

# %%
# perform a training and testing split, using 76% of the data for
# training and 24% for evaluation
(trainX, testX, trainY, testY) = train_test_split(np.array(data),	np.array(labels), test_size=0.24, shuffle=True)
print(trainX.shape)
print(testX.shape)
# Out:
# (443, 64, 64, 3)
# (141, 64, 64, 3)

# %%
from keras.layers import Convolution2D, MaxPool2D
from keras.models import Sequential
from keras.layers.core import Flatten, Dense

model1 = Sequential()
model1.add(Convolution2D(8,(3,3), activation='relu', input_shape=(64,64,3)))
model1.add(MaxPool2D(2,2))
model1.add(Convolution2D(16,(3,3), activation='relu'))
model1.add(MaxPool2D(2,2))
# fully connected layers
model1.add(Flatten())
model1.add(Dense(100, activation='relu'))
model1.add(Dense(5, activation='softmax'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 8)         224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 8)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 29, 29, 16)        1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 100)               313700
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 505
# =================================================================
# Total params: 315,597
# Trainable params: 315,597
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.models import Sequential
from keras.layers.core import Flatten
from keras.layers.core import Dense

model = Sequential(
    [
     Flatten(input_shape=(64*64*3,)),
     Dense(100, activation="relu", name="layer1"),
     Dense(16, activation="relu", name="layer2"),
     Dense(16, activation="relu", name="layer3"),
     Dense(3, activation="softmax", name="layer4"),
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 12288)             0
# _________________________________________________________________
# layer1 (Dense)               (None, 100)               1228900
# _________________________________________________________________
# layer2 (Dense)               (None, 16)                1616
# _________________________________________________________________
# layer3 (Dense)               (None, 16)                272
# _________________________________________________________________
# layer4 (Dense)               (None, 3)                 51
# =================================================================
# Total params: 1,230,839
# Trainable params: 1,230,839
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the model using the Adam optimizer
print("[INFO] training network...")
opt = Adam(lr=1e-3, decay=1e-3 / 50)
model1.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
H = model1.fit(trainX, trainY, validation_data=(testX, testY), epochs=30, batch_size=32)
# Out:
# [INFO] training network...
# Epoch 1/30
# 14/14 [==============================] - 1s 78ms/step - loss: 1.6118 - accuracy: 0.2460 - val_loss: 1.5480 - val_accuracy: 0.2695
# Epoch 2/30
# 14/14 [==============================] - 1s 68ms/step - loss: 1.4129 - accuracy: 0.4221 - val_loss: 1.3818 - val_accuracy: 0.4539
# Epoch 3/30
# 14/14 [==============================] - 1s 68ms/step - loss: 1.2396 - accuracy: 0.5282 - val_loss: 1.2230 - val_accuracy: 0.5603
# Epoch 4/30
# 14/14 [==============================] - 1s 68ms/step - loss: 1.0792 - accuracy: 0.5801 - val_loss: 1.2252 - val_accuracy: 0.4681
# Epoch 5/30
# 14/14 [==============================] - 1s 68ms/step - loss: 0.9352 - accuracy: 0.6637 - val_loss: 1.0269 - val_accuracy: 0.6028
# Epoch 6/30
# 14/14 [==============================] - 1s 68ms/step - loss: 0.7859 - accuracy: 0.6998 - val_loss: 1.0551 - val_accuracy: 0.5957
# Epoch 7/30
# 14/14 [==============================] - 1s 68ms/step - loss: 0.7307 - accuracy: 0.7381 - val_loss: 0.9489 - val_accuracy: 0.6454
# Epoch 8/30
# 14/14 [==============================] - 1s 68ms/step - loss: 0.6596 - accuracy: 0.7585 - val_loss: 0.9237 - val_accuracy: 0.6454
# Epoch 9/30
# 14/14 [==============================] - 1s 68ms/step - loss: 0.5583 - accuracy: 0.8149 - val_loss: 0.8620 - val_accuracy: 0.6525
# Epoch 10/30
# 14/14 [==============================] - 1s 68ms/step - loss: 0.4994 - accuracy: 0.8352 - val_loss: 0.8964 - val_accuracy: 0.6950
# Epoch 11/30
# 14/14 [==============================] - 1s 69ms/step - loss: 0.4549 - accuracy: 0.8420 - val_loss: 0.8835 - val_accuracy: 0.6738
# Epoch 12/30
# 14/14 [==============================] - 1s 68ms/step - loss: 0.4374 - accuracy: 0.8488 - val_loss: 0.8640 - val_accuracy: 0.6454
# Epoch 13/30
# 14/14 [==============================] - 1s 68ms/step - loss: 0.3968 - accuracy: 0.8736 - val_loss: 0.8720 - val_accuracy: 0.6596
# Epoch 14/30
# 14/14 [==============================] - 1s 68ms/step - loss: 0.3301 - accuracy: 0.8984 - val_loss: 0.9687 - val_accuracy: 0.6950
# Epoch 15/30
# 14/14 [==============================] - 1s 68ms/step - loss: 0.2982 - accuracy: 0.9233 - val_loss: 0.8293 - val_accuracy: 0.7376
# Epoch 16/30
# 14/14 [==============================] - 1s 69ms/step - loss: 0.2516 - accuracy: 0.9323 - val_loss: 0.8400 - val_accuracy: 0.7376
# Epoch 17/30
# 14/14 [==============================] - 1s 69ms/step - loss: 0.2315 - accuracy: 0.9278 - val_loss: 0.8259 - val_accuracy: 0.7447
# Epoch 18/30
# 14/14 [==============================] - 1s 69ms/step - loss: 0.1985 - accuracy: 0.9616 - val_loss: 0.8470 - val_accuracy: 0.7305
# Epoch 19/30
# 14/14 [==============================] - 1s 69ms/step - loss: 0.1818 - accuracy: 0.9481 - val_loss: 0.8487 - val_accuracy: 0.7163
# Epoch 20/30
# 14/14 [==============================] - 1s 69ms/step - loss: 0.1590 - accuracy: 0.9571 - val_loss: 0.8032 - val_accuracy: 0.7305
# Epoch 21/30
# 14/14 [==============================] - 1s 68ms/step - loss: 0.1372 - accuracy: 0.9752 - val_loss: 0.8699 - val_accuracy: 0.7163
# Epoch 22/30
# 14/14 [==============================] - 1s 69ms/step - loss: 0.1443 - accuracy: 0.9661 - val_loss: 0.8375 - val_accuracy: 0.7447
# Epoch 23/30
# 14/14 [==============================] - 1s 69ms/step - loss: 0.1342 - accuracy: 0.9661 - val_loss: 0.8454 - val_accuracy: 0.7447
# Epoch 24/30
# 14/14 [==============================] - 1s 67ms/step - loss: 0.1104 - accuracy: 0.9774 - val_loss: 0.9343 - val_accuracy: 0.7447
# Epoch 25/30
# 14/14 [==============================] - 1s 69ms/step - loss: 0.0959 - accuracy: 0.9774 - val_loss: 0.8566 - val_accuracy: 0.7447
# Epoch 26/30
# 14/14 [==============================] - 1s 68ms/step - loss: 0.1154 - accuracy: 0.9729 - val_loss: 0.8304 - val_accuracy: 0.7376
# Epoch 27/30
# 14/14 [==============================] - 1s 68ms/step - loss: 0.0847 - accuracy: 0.9819 - val_loss: 0.9556 - val_accuracy: 0.7234
# Epoch 28/30
# 14/14 [==============================] - 1s 69ms/step - loss: 0.0667 - accuracy: 0.9910 - val_loss: 0.9322 - val_accuracy: 0.7518
# Epoch 29/30
# 14/14 [==============================] - 1s 68ms/step - loss: 0.0569 - accuracy: 0.9910 - val_loss: 0.8888 - val_accuracy: 0.7447
# Epoch 30/30
# 14/14 [==============================] - 1s 69ms/step - loss: 0.0482 - accuracy: 0.9932 - val_loss: 0.9342 - val_accuracy: 0.7447

# %%
import matplotlib.pyplot as plt

print(H.history.keys())
# summarize history for accuracy
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model1.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=lb.classes_))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#       GMB_01       0.64      0.54      0.58        26
#       GMB_02       0.74      0.85      0.79        33
#       GMB_03       0.92      0.85      0.88        26
#       GMB_04       0.81      0.63      0.71        35
#       GMB_05       0.63      0.90      0.75        21
#
#     accuracy                           0.74       141
#    macro avg       0.75      0.75      0.74       141
# weighted avg       0.76      0.74      0.74       141

# %%
model1.save('nmodel_scene')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: nmodel_scene/assets

# %%
import cv2
import matplotlib.pyplot as plt
image1='IMG_20200814_133326_HDR.jpg'

# %%
img_array = cv2.imread(image1)
plt.imshow(img_array)
plt.show()
# print(type(img_array))

# %%
image_testing = Image.open('IMG_20200814_133326_HDR.jpg')
image_testing = np.array(image_testing.resize((64, 64))) / 255.0
image_testing.shape
# Out:
# (64, 64, 3)

# %%
image_testing = np.expand_dims(image_testing, axis=0)
print(image_testing.shape)
# Out:
# (1, 64, 64, 3)

# %%
output = model1.predict(image_testing, 1)
print(output)
print(lb.classes_[output.argmax(axis=1)])
# Out:
# [[7.5930938e-02 9.1982639e-01 4.8908146e-07 3.0222407e-03 1.2200254e-03]]
# ['GMB_02']
